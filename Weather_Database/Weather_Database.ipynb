# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nanortalik
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | portland
# Processing Record 4 of Set 1 | talnakh
# Processing Record 5 of Set 1 | kastrakion
# Processing Record 6 of Set 1 | lavrentiya
# Processing Record 7 of Set 1 | haines junction
# Processing Record 8 of Set 1 | aklavik
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | arraial do cabo
# Processing Record 11 of Set 1 | severo-kurilsk
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | gazojak
# Processing Record 14 of Set 1 | kirakira
# Processing Record 15 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 1 | vestmannaeyjar
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | bambous virieux
# Processing Record 19 of Set 1 | carutapera
# Processing Record 20 of Set 1 | isangel
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | sovetskaya
# Processing Record 23 of Set 1 | kaitong
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | termiz
# Processing Record 26 of Set 1 | torbay
# Processing Record 27 of Set 1 | mayo
# Processing Record 28 of Set 1 | wajima
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | belmonte
# Processing Record 31 of Set 1 | ilulissat
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | nouadhibou
# Processing Record 34 of Set 1 | chuy
# Processing Record 35 of Set 1 | olga
# Processing Record 36 of Set 1 | bolong
# Processing Record 37 of Set 1 | saint anthony
# Processing Record 38 of Set 1 | roald
# Processing Record 39 of Set 1 | nikolskoye
# Processing Record 40 of Set 1 | marrakesh
# Processing Record 41 of Set 1 | sile
# Processing Record 42 of Set 1 | ternate
# Processing Record 43 of Set 1 | los llanos de aridane
# Processing Record 44 of Set 1 | airai
# Processing Record 45 of Set 1 | lompoc
# Processing Record 46 of Set 1 | kathmandu
# Processing Record 47 of Set 1 | dankov
# Processing Record 48 of Set 1 | point fortin
# Processing Record 49 of Set 1 | san patricio
# Processing Record 50 of Set 1 | rincon
# Processing Record 1 of Set 2 | rikitea
# Processing Record 2 of Set 2 | arrecife
# Processing Record 3 of Set 2 | saint-philippe
# Processing Record 4 of Set 2 | muros
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | port elizabeth
# Processing Record 8 of Set 2 | fort nelson
# Processing Record 9 of Set 2 | sharjah
# Processing Record 10 of Set 2 | royan
# Processing Record 11 of Set 2 | roanoke rapids
# Processing Record 12 of Set 2 | nelson bay
# Processing Record 13 of Set 2 | ribeira grande
# Processing Record 14 of Set 2 | srednekolymsk
# Processing Record 15 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | ancud
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | bam
# Processing Record 22 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | codrington
# Processing Record 25 of Set 2 | karratha
# Processing Record 26 of Set 2 | bulancak
# Processing Record 27 of Set 2 | nishihara
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | rognan
# Processing Record 30 of Set 2 | chapais
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 2 | birsk
# Processing Record 35 of Set 2 | alofi
# Processing Record 36 of Set 2 | sorland
# Processing Record 37 of Set 2 | el alto
# Processing Record 38 of Set 2 | east london
# Processing Record 39 of Set 2 | valleyview
# Processing Record 40 of Set 2 | calintaan
# Processing Record 41 of Set 2 | sinnamary
# Processing Record 42 of Set 2 | port blair
# Processing Record 43 of Set 2 | albany
# Processing Record 44 of Set 2 | ushtobe
# Processing Record 45 of Set 2 | pinawa
# Processing Record 46 of Set 2 | carnarvon
# Processing Record 47 of Set 2 | takoradi
# Processing Record 48 of Set 2 | ketchikan
# Processing Record 49 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 2 | atasu
# Processing Record 1 of Set 3 | sambalpur
# Processing Record 2 of Set 3 | mahebourg
# Processing Record 3 of Set 3 | chokurdakh
# Processing Record 4 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 3 | camacha
# Processing Record 6 of Set 3 | saucillo
# Processing Record 7 of Set 3 | iqaluit
# Processing Record 8 of Set 3 | clyde river
# Processing Record 9 of Set 3 | sao filipe
# Processing Record 10 of Set 3 | maumere
# Processing Record 11 of Set 3 | washougal
# Processing Record 12 of Set 3 | lagoa
# Processing Record 13 of Set 3 | stulovo
# Processing Record 14 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 3 | longyearbyen
# Processing Record 16 of Set 3 | atuona
# Processing Record 17 of Set 3 | jamestown
# Processing Record 18 of Set 3 | guiyang
# Processing Record 19 of Set 3 | lengshuitan
# Processing Record 20 of Set 3 | narsaq
# Processing Record 21 of Set 3 | sitka
# Processing Record 22 of Set 3 | faanui
# Processing Record 23 of Set 3 | southbridge
# Processing Record 24 of Set 3 | georgetown
# Processing Record 25 of Set 3 | straumen
# Processing Record 26 of Set 3 | raub
# Processing Record 27 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 3 | svoge
# Processing Record 29 of Set 3 | bairiki
# Processing Record 30 of Set 3 | cabra
# Processing Record 31 of Set 3 | saint-pierre
# Processing Record 32 of Set 3 | provideniya
# Processing Record 33 of Set 3 | bereda
# Processing Record 34 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 3 | tautira
# Processing Record 36 of Set 3 | san andres del rabanedo
# Processing Record 37 of Set 3 | geraldton
# Processing Record 38 of Set 3 | puerto ayora
# Processing Record 39 of Set 3 | bagamoyo
# Processing Record 40 of Set 3 | coahuayana
# Processing Record 41 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 3 | saiha
# Processing Record 44 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | biak
# Processing Record 47 of Set 3 | sumbawa
# City not found. Skipping...
# Processing Record 48 of Set 3 | kahului
# Processing Record 49 of Set 3 | beisfjord
# Processing Record 50 of Set 3 | kaitangata
# Processing Record 1 of Set 4 | umm lajj
# Processing Record 2 of Set 4 | esperance
# Processing Record 3 of Set 4 | maarianhamina
# Processing Record 4 of Set 4 | turukhansk
# Processing Record 5 of Set 4 | barrow
# Processing Record 6 of Set 4 | mar del plata
# Processing Record 7 of Set 4 | muzquiz
# City not found. Skipping...
# Processing Record 8 of Set 4 | bowen
# Processing Record 9 of Set 4 | komsomolskiy
# Processing Record 10 of Set 4 | dingle
# Processing Record 11 of Set 4 | sao jose da coroa grande
# Processing Record 12 of Set 4 | chabahar
# Processing Record 13 of Set 4 | thinadhoo
# Processing Record 14 of Set 4 | lismore
# Processing Record 15 of Set 4 | lahij
# Processing Record 16 of Set 4 | wagga wagga
# Processing Record 17 of Set 4 | castro
# Processing Record 18 of Set 4 | a
# City not found. Skipping...
# Processing Record 19 of Set 4 | ende
# Processing Record 20 of Set 4 | konevo
# Processing Record 21 of Set 4 | upernavik
# Processing Record 22 of Set 4 | caucaguita
# Processing Record 23 of Set 4 | cabo san lucas
# Processing Record 24 of Set 4 | qaanaaq
# Processing Record 25 of Set 4 | hofn
# Processing Record 26 of Set 4 | san cristobal
# Processing Record 27 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 4 | salalah
# Processing Record 29 of Set 4 | punta arenas
# Processing Record 30 of Set 4 | rohru
# Processing Record 31 of Set 4 | hermanus
# Processing Record 32 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 4 | fairbanks
# Processing Record 34 of Set 4 | new norfolk
# Processing Record 35 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 4 | mango
# Processing Record 37 of Set 4 | westport
# Processing Record 38 of Set 4 | mandalgovi
# Processing Record 39 of Set 4 | kavieng
# Processing Record 40 of Set 4 | mount gambier
# Processing Record 41 of Set 4 | bengkulu
# Processing Record 42 of Set 4 | filingue
# Processing Record 43 of Set 4 | bredasdorp
# Processing Record 44 of Set 4 | khatanga
# Processing Record 45 of Set 4 | ahuimanu
# Processing Record 46 of Set 4 | grants
# Processing Record 47 of Set 4 | mbanza-ngungu
# Processing Record 48 of Set 4 | eganville
# Processing Record 49 of Set 4 | pisco
# Processing Record 50 of Set 4 | sioux lookout
# Processing Record 1 of Set 5 | tiksi
# Processing Record 2 of Set 5 | gargzdai
# Processing Record 3 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 5 | uvalde
# Processing Record 5 of Set 5 | ust-kuyga
# Processing Record 6 of Set 5 | qaqortoq
# Processing Record 7 of Set 5 | asyut
# Processing Record 8 of Set 5 | tessalit
# Processing Record 9 of Set 5 | udachnyy
# Processing Record 10 of Set 5 | homer
# Processing Record 11 of Set 5 | indiaroba
# Processing Record 12 of Set 5 | leningradskiy
# Processing Record 13 of Set 5 | hamilton
# Processing Record 14 of Set 5 | beira
# Processing Record 15 of Set 5 | eureka
# Processing Record 16 of Set 5 | barcelos
# Processing Record 17 of Set 5 | porosozero
# Processing Record 18 of Set 5 | kuala sungai baru
# Processing Record 19 of Set 5 | saldanha
# Processing Record 20 of Set 5 | hami
# Processing Record 21 of Set 5 | ambulu
# Processing Record 22 of Set 5 | lokomotivnyy
# Processing Record 23 of Set 5 | ankazoabo
# Processing Record 24 of Set 5 | anadyr
# Processing Record 25 of Set 5 | baker city
# Processing Record 26 of Set 5 | patharia
# Processing Record 27 of Set 5 | ranong
# Processing Record 28 of Set 5 | scottsbluff
# Processing Record 29 of Set 5 | bilibino
# Processing Record 30 of Set 5 | sena madureira
# Processing Record 31 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 5 | funadhoo
# Processing Record 33 of Set 5 | emporia
# Processing Record 34 of Set 5 | kloulklubed
# Processing Record 35 of Set 5 | makushino
# Processing Record 36 of Set 5 | vanimo
# Processing Record 37 of Set 5 | plettenberg bay
# Processing Record 38 of Set 5 | cabedelo
# Processing Record 39 of Set 5 | curaca
# Processing Record 40 of Set 5 | ostrovnoy
# Processing Record 41 of Set 5 | xuddur
# Processing Record 42 of Set 5 | one hundred mile house
# City not found. Skipping...
# Processing Record 43 of Set 5 | menongue
# Processing Record 44 of Set 5 | batagay-alyta
# Processing Record 45 of Set 5 | andenes
# Processing Record 46 of Set 5 | kodiak
# Processing Record 47 of Set 5 | port-gentil
# Processing Record 48 of Set 5 | kayerkan
# Processing Record 49 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 50 of Set 5 | puerto quijarro
# Processing Record 1 of Set 6 | yershov
# Processing Record 2 of Set 6 | sarangani
# Processing Record 3 of Set 6 | tasiilaq
# Processing Record 4 of Set 6 | shelburne
# Processing Record 5 of Set 6 | karsun
# Processing Record 6 of Set 6 | mormugao
# Processing Record 7 of Set 6 | cidreira
# Processing Record 8 of Set 6 | churapcha
# Processing Record 9 of Set 6 | okandja
# City not found. Skipping...
# Processing Record 10 of Set 6 | aleppo
# Processing Record 11 of Set 6 | joensuu
# Processing Record 12 of Set 6 | ahipara
# Processing Record 13 of Set 6 | diban
# Processing Record 14 of Set 6 | santiago del estero
# Processing Record 15 of Set 6 | orange walk
# Processing Record 16 of Set 6 | sao joao da barra
# Processing Record 17 of Set 6 | abu kamal
# Processing Record 18 of Set 6 | hun
# Processing Record 19 of Set 6 | tual
# Processing Record 20 of Set 6 | teya
# Processing Record 21 of Set 6 | klaksvik
# Processing Record 22 of Set 6 | pacific grove
# Processing Record 23 of Set 6 | dinsor
# City not found. Skipping...
# Processing Record 24 of Set 6 | souillac
# Processing Record 25 of Set 6 | fortuna
# Processing Record 26 of Set 6 | saint george
# Processing Record 27 of Set 6 | santa marta
# Processing Record 28 of Set 6 | soyo
# Processing Record 29 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 6 | ghanzi
# Processing Record 31 of Set 6 | victoria
# Processing Record 32 of Set 6 | gidam
# Processing Record 33 of Set 6 | saskylakh
# Processing Record 34 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 6 | havoysund
# Processing Record 36 of Set 6 | henties bay
# Processing Record 37 of Set 6 | verkhnevilyuysk
# Processing Record 38 of Set 6 | sulangan
# Processing Record 39 of Set 6 | zhanaozen
# Processing Record 40 of Set 6 | dikson
# Processing Record 41 of Set 6 | kunzell
# Processing Record 42 of Set 6 | caravelas
# Processing Record 43 of Set 6 | carnot
# Processing Record 44 of Set 6 | fairlie
# Processing Record 45 of Set 6 | bulungu
# Processing Record 46 of Set 6 | pandan
# Processing Record 47 of Set 6 | puerto colombia
# Processing Record 48 of Set 6 | zenzeli
# Processing Record 49 of Set 6 | san buenaventura
# Processing Record 50 of Set 6 | ruteng
# Processing Record 1 of Set 7 | burica
# City not found. Skipping...
# Processing Record 2 of Set 7 | bogorodskoye
# Processing Record 3 of Set 7 | erzin
# Processing Record 4 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 5 of Set 7 | opuwo
# Processing Record 6 of Set 7 | barinitas
# Processing Record 7 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 10 of Set 7 | tucumcari
# Processing Record 11 of Set 7 | balsas
# Processing Record 12 of Set 7 | bafoulabe
# Processing Record 13 of Set 7 | tiarei
# Processing Record 14 of Set 7 | kruisfontein
# Processing Record 15 of Set 7 | jujuy
# City not found. Skipping...
# Processing Record 16 of Set 7 | kavaratti
# Processing Record 17 of Set 7 | khartoum
# Processing Record 18 of Set 7 | sandakan
# Processing Record 19 of Set 7 | beloha
# Processing Record 20 of Set 7 | bambanglipuro
# Processing Record 21 of Set 7 | basco
# Processing Record 22 of Set 7 | vila franca do campo
# Processing Record 23 of Set 7 | kolokani
# Processing Record 24 of Set 7 | sherbrooke
# Processing Record 25 of Set 7 | nador
# Processing Record 26 of Set 7 | chernyshevskiy
# Processing Record 27 of Set 7 | ponta do sol
# Processing Record 28 of Set 7 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 29 of Set 7 | chadan
# Processing Record 30 of Set 7 | tevaitoa
# Processing Record 31 of Set 7 | touros
# Processing Record 32 of Set 7 | kholtoson
# Processing Record 33 of Set 7 | lukovetskiy
# Processing Record 34 of Set 7 | praia da vitoria
# Processing Record 35 of Set 7 | broken hill
# Processing Record 36 of Set 7 | meulaboh
# Processing Record 37 of Set 7 | rockport
# Processing Record 38 of Set 7 | pritzwalk
# Processing Record 39 of Set 7 | shintomi
# Processing Record 40 of Set 7 | adrar
# Processing Record 41 of Set 7 | zemio
# Processing Record 42 of Set 7 | aden
# Processing Record 43 of Set 7 | porto torres
# Processing Record 44 of Set 7 | zacatlan
# Processing Record 45 of Set 7 | itoman
# Processing Record 46 of Set 7 | namatanai
# Processing Record 47 of Set 7 | vestmanna
# Processing Record 48 of Set 7 | yeppoon
# Processing Record 49 of Set 7 | safranbolu
# Processing Record 50 of Set 7 | bondoukou
# Processing Record 1 of Set 8 | lasa
# Processing Record 2 of Set 8 | nalut
# Processing Record 3 of Set 8 | katsuura
# Processing Record 4 of Set 8 | carbonia
# Processing Record 5 of Set 8 | namibe
# Processing Record 6 of Set 8 | taoudenni
# Processing Record 7 of Set 8 | lebu
# Processing Record 8 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 9 of Set 8 | cayenne
# Processing Record 10 of Set 8 | corrente
# Processing Record 11 of Set 8 | ichalkaranji
# Processing Record 12 of Set 8 | havre-saint-pierre
# Processing Record 13 of Set 8 | yeniseysk
# Processing Record 14 of Set 8 | barranca
# Processing Record 15 of Set 8 | kysyl-syr
# Processing Record 16 of Set 8 | solnechnyy
# Processing Record 17 of Set 8 | half moon bay
# Processing Record 18 of Set 8 | marzuq
# Processing Record 19 of Set 8 | ulaangom
# Processing Record 20 of Set 8 | hammerfest
# Processing Record 21 of Set 8 | abalak
# Processing Record 22 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 23 of Set 8 | bantogon
# Processing Record 24 of Set 8 | leh
# Processing Record 25 of Set 8 | guapo
# Processing Record 26 of Set 8 | makakilo city
# Processing Record 27 of Set 8 | pitimbu
# Processing Record 28 of Set 8 | noumea
# Processing Record 29 of Set 8 | daru
# Processing Record 30 of Set 8 | tilichiki
# Processing Record 31 of Set 8 | karaton
# Processing Record 32 of Set 8 | goderich
# Processing Record 33 of Set 8 | pangody
# Processing Record 34 of Set 8 | mercedes
# Processing Record 35 of Set 8 | la romana
# Processing Record 36 of Set 8 | vostok
# Processing Record 37 of Set 8 | moose factory
# Processing Record 38 of Set 8 | spiridonovka
# Processing Record 39 of Set 8 | choucheng
# City not found. Skipping...
# Processing Record 40 of Set 8 | high rock
# Processing Record 41 of Set 8 | smithers
# Processing Record 42 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 43 of Set 8 | mechanicsville
# Processing Record 44 of Set 8 | aykhal
# Processing Record 45 of Set 8 | sao lourenco do sul
# Processing Record 46 of Set 8 | toamasina
# Processing Record 47 of Set 8 | naze
# Processing Record 48 of Set 8 | wiang sa
# Processing Record 49 of Set 8 | banda aceh
# Processing Record 50 of Set 8 | lima
# Processing Record 1 of Set 9 | payyannur
# Processing Record 2 of Set 9 | sibu
# Processing Record 3 of Set 9 | rundu
# Processing Record 4 of Set 9 | gueret
# Processing Record 5 of Set 9 | chalchihuites
# Processing Record 6 of Set 9 | taree
# Processing Record 7 of Set 9 | camana
# Processing Record 8 of Set 9 | tlaltenango
# Processing Record 9 of Set 9 | evensk
# Processing Record 10 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 11 of Set 9 | urucui
# Processing Record 12 of Set 9 | cuamba
# Processing Record 13 of Set 9 | bathsheba
# Processing Record 14 of Set 9 | nelson
# Processing Record 15 of Set 9 | kafanchan
# Processing Record 16 of Set 9 | porto novo
# Processing Record 17 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 18 of Set 9 | saint-ambroise
# Processing Record 19 of Set 9 | sakaiminato
# Processing Record 20 of Set 9 | iskele
# Processing Record 21 of Set 9 | bernal
# Processing Record 22 of Set 9 | raudeberg
# Processing Record 23 of Set 9 | tucurui
# Processing Record 24 of Set 9 | bull savanna
# Processing Record 25 of Set 9 | cap-aux-meules
# Processing Record 26 of Set 9 | senmonorom
# City not found. Skipping...
# Processing Record 27 of Set 9 | tolaga bay
# Processing Record 28 of Set 9 | rocha
# Processing Record 29 of Set 9 | poum
# Processing Record 30 of Set 9 | eresos
# Processing Record 31 of Set 9 | kenai
# Processing Record 32 of Set 9 | padang
# Processing Record 33 of Set 9 | hervey bay
# Processing Record 34 of Set 9 | kralendijk
# Processing Record 35 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 9 | port shepstone
# Processing Record 37 of Set 9 | pevek
# Processing Record 38 of Set 9 | lethem
# Processing Record 39 of Set 9 | yulara
# Processing Record 40 of Set 9 | oistins
# Processing Record 41 of Set 9 | tanabe
# Processing Record 42 of Set 9 | biskamzha
# Processing Record 43 of Set 9 | khambhat
# Processing Record 44 of Set 9 | rongcheng
# Processing Record 45 of Set 9 | la ronge
# Processing Record 46 of Set 9 | komsomolskoye
# Processing Record 47 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 9 | alta
# Processing Record 49 of Set 9 | mangrol
# Processing Record 50 of Set 9 | anito
# Processing Record 1 of Set 10 | uva
# Processing Record 2 of Set 10 | san quintin
# Processing Record 3 of Set 10 | bestobe
# Processing Record 4 of Set 10 | nefteyugansk
# Processing Record 5 of Set 10 | viga
# Processing Record 6 of Set 10 | tsogni
# Processing Record 7 of Set 10 | pangai
# Processing Record 8 of Set 10 | anloga
# Processing Record 9 of Set 10 | boralday
# Processing Record 10 of Set 10 | radishchevo
# Processing Record 11 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 12 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 13 of Set 10 | kidal
# Processing Record 14 of Set 10 | kamaishi
# Processing Record 15 of Set 10 | bahia de caraquez
# Processing Record 16 of Set 10 | paamiut
# Processing Record 17 of Set 10 | hambantota
# Processing Record 18 of Set 10 | altay
# Processing Record 19 of Set 10 | kindu
# Processing Record 20 of Set 10 | bonavista
# Processing Record 21 of Set 10 | warrnambool
# Processing Record 22 of Set 10 | dubbo
# Processing Record 23 of Set 10 | aldergrove
# Processing Record 24 of Set 10 | san policarpo
# Processing Record 25 of Set 10 | nizhniye sergi
# Processing Record 26 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 27 of Set 10 | shenjiamen
# Processing Record 28 of Set 10 | cervo
# Processing Record 29 of Set 10 | luena
# Processing Record 30 of Set 10 | ossora
# Processing Record 31 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 10 | kihei
# Processing Record 33 of Set 10 | christchurch
# Processing Record 34 of Set 10 | bar harbor
# Processing Record 35 of Set 10 | araouane
# Processing Record 36 of Set 10 | eyl
# Processing Record 37 of Set 10 | jiroft
# City not found. Skipping...
# Processing Record 38 of Set 10 | donghai
# Processing Record 39 of Set 10 | adamas
# Processing Record 40 of Set 10 | winona
# Processing Record 41 of Set 10 | rio gallegos
# Processing Record 42 of Set 10 | faya
# Processing Record 43 of Set 10 | gazanjyk
# Processing Record 44 of Set 10 | perbaungan
# Processing Record 45 of Set 10 | cherskiy
# Processing Record 46 of Set 10 | qasigiannguit
# Processing Record 47 of Set 10 | omurtag
# Processing Record 48 of Set 10 | santa fe
# Processing Record 49 of Set 10 | caapucu
# Processing Record 50 of Set 10 | samarai
# Processing Record 1 of Set 11 | navirai
# Processing Record 2 of Set 11 | khomutovka
# Processing Record 3 of Set 11 | macapa
# Processing Record 4 of Set 11 | puebloviejo
# Processing Record 5 of Set 11 | iquitos
# Processing Record 6 of Set 11 | jaque
# Processing Record 7 of Set 11 | dakar
# Processing Record 8 of Set 11 | norman wells
# Processing Record 9 of Set 11 | yurino
# Processing Record 10 of Set 11 | nueva gerona
# Processing Record 11 of Set 11 | nara
# Processing Record 12 of Set 11 | mandaguacu
# Processing Record 13 of Set 11 | jacareacanga
# Processing Record 14 of Set 11 | howard springs
# Processing Record 15 of Set 11 | arlit
# Processing Record 16 of Set 11 | port hedland
# Processing Record 17 of Set 11 | malartic
# Processing Record 18 of Set 11 | chumphon
# Processing Record 19 of Set 11 | cravo norte
# Processing Record 20 of Set 11 | bodden town
# Processing Record 21 of Set 11 | labuhan
# Processing Record 22 of Set 11 | seoul
# Processing Record 23 of Set 11 | greytown
# Processing Record 24 of Set 11 | mamou
# Processing Record 25 of Set 11 | zavodouspenskoye
# Processing Record 26 of Set 11 | saint-francois
# Processing Record 27 of Set 11 | kropotkin
# Processing Record 28 of Set 11 | quatre cocos
# Processing Record 29 of Set 11 | usinsk
# Processing Record 30 of Set 11 | severnyy
# Processing Record 31 of Set 11 | mareeba
# Processing Record 32 of Set 11 | okhotsk
# Processing Record 33 of Set 11 | male
# Processing Record 34 of Set 11 | sol-iletsk
# Processing Record 35 of Set 11 | ivanivka
# Processing Record 36 of Set 11 | belogradcik
# City not found. Skipping...
# Processing Record 37 of Set 11 | guarapari
# Processing Record 38 of Set 11 | dahanu
# Processing Record 39 of Set 11 | comodoro rivadavia
# Processing Record 40 of Set 11 | sakakah
# Processing Record 41 of Set 11 | placido de castro
# Processing Record 42 of Set 11 | amuntai
# Processing Record 43 of Set 11 | itum-kale
# Processing Record 44 of Set 11 | mackay
# Processing Record 45 of Set 11 | lapeer
# Processing Record 46 of Set 11 | amga
# Processing Record 47 of Set 11 | yar-sale
# Processing Record 48 of Set 11 | kibungo
# Processing Record 49 of Set 11 | champerico
# Processing Record 50 of Set 11 | kurakh
# Processing Record 1 of Set 12 | hasaki
# Processing Record 2 of Set 12 | saint-georges
# Processing Record 3 of Set 12 | malesici
# Processing Record 4 of Set 12 | bouna
# Processing Record 5 of Set 12 | kalmar
# Processing Record 6 of Set 12 | kurayoshi
# Processing Record 7 of Set 12 | iset
# Processing Record 8 of Set 12 | diamantino
# Processing Record 9 of Set 12 | dunedin
# Processing Record 10 of Set 12 | gamba
# Processing Record 11 of Set 12 | cockburn town
# Processing Record 12 of Set 12 | koungheul
# Processing Record 13 of Set 12 | grindavik
# Processing Record 14 of Set 12 | halifax
# Processing Record 15 of Set 12 | guerrero negro
# Processing Record 16 of Set 12 | mount isa
# Processing Record 17 of Set 12 | elko
# Processing Record 18 of Set 12 | olafsvik
# Processing Record 19 of Set 12 | loreto
# Processing Record 20 of Set 12 | nuevo progreso
# Processing Record 21 of Set 12 | binzhou
# Processing Record 22 of Set 12 | balad
# Processing Record 23 of Set 12 | nakhon phanom
# Processing Record 24 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 25 of Set 12 | leticia
# Processing Record 26 of Set 12 | auki
# Processing Record 27 of Set 12 | lapithos
# Processing Record 28 of Set 12 | hirson
# Processing Record 29 of Set 12 | phalodi
# Processing Record 30 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 12 | hattiesburg
# Processing Record 32 of Set 12 | trincomalee
# Processing Record 33 of Set 12 | asau
# Processing Record 34 of Set 12 | prince rupert
# Processing Record 35 of Set 12 | saint-louis
# Processing Record 36 of Set 12 | blahodatne
# Processing Record 37 of Set 12 | sibolga
# Processing Record 38 of Set 12 | isla vista
# Processing Record 39 of Set 12 | kulhudhuffushi
# Processing Record 40 of Set 12 | tuatapere
# Processing Record 41 of Set 12 | durango
# Processing Record 42 of Set 12 | marsh harbour
# Processing Record 43 of Set 12 | clifton
# Processing Record 44 of Set 12 | port lincoln
# Processing Record 45 of Set 12 | grand gaube
# Processing Record 46 of Set 12 | oksfjord
# Processing Record 47 of Set 12 | ballina
# Processing Record 48 of Set 12 | elizabeth city
# Processing Record 49 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 12 | talovaya
# Processing Record 1 of Set 13 | tengushevo
# Processing Record 2 of Set 13 | shihezi
# Processing Record 3 of Set 13 | ormara
# Processing Record 4 of Set 13 | leshukonskoye
# Processing Record 5 of Set 13 | kungurtug
# Processing Record 6 of Set 13 | marawi
# Processing Record 7 of Set 13 | nadym
# Processing Record 8 of Set 13 | mincivan
# Processing Record 9 of Set 13 | iralaya
# Processing Record 10 of Set 13 | gornopravdinsk
# Processing Record 11 of Set 13 | jiangyou
# Processing Record 12 of Set 13 | nunoa
# Processing Record 13 of Set 13 | wanning
# Processing Record 14 of Set 13 | puerto lopez
# Processing Record 15 of Set 13 | port augusta
# Processing Record 16 of Set 13 | bardiyah
# Processing Record 17 of Set 13 | tecoanapa
# Processing Record 18 of Set 13 | vao
# Processing Record 19 of Set 13 | bandarbeyla
# Processing Record 20 of Set 13 | la ligua
# Processing Record 21 of Set 13 | ust-nera
# Processing Record 22 of Set 13 | iisalmi
# Processing Record 23 of Set 13 | nikel
# Processing Record 24 of Set 13 | tarko-sale
# Processing Record 25 of Set 13 | byron bay
# Processing Record 26 of Set 13 | tlahualilo
# City not found. Skipping...
# Processing Record 27 of Set 13 | merauke
# Processing Record 28 of Set 13 | pedernales
# Processing Record 29 of Set 13 | kisangani
# Processing Record 30 of Set 13 | kangaba
# Processing Record 31 of Set 13 | farah
# Processing Record 32 of Set 13 | flin flon
# Processing Record 33 of Set 13 | nenjiang
# Processing Record 34 of Set 13 | axim
# Processing Record 35 of Set 13 | verkhnetulomskiy
# Processing Record 36 of Set 13 | talara
# Processing Record 37 of Set 13 | puerto suarez
# Processing Record 38 of Set 13 | sidney
# Processing Record 39 of Set 13 | kasempa
# Processing Record 40 of Set 13 | iskateley
# Processing Record 41 of Set 13 | santa rosa
# Processing Record 42 of Set 13 | olinda
# Processing Record 43 of Set 13 | nizhniy kuranakh
# Processing Record 44 of Set 13 | aswan
# Processing Record 45 of Set 13 | kamphaeng phet
# Processing Record 46 of Set 13 | kununurra
# Processing Record 47 of Set 13 | bolshiye uki
# City not found. Skipping...
# Processing Record 48 of Set 13 | tuy hoa
# Processing Record 49 of Set 13 | maniitsoq
# Processing Record 50 of Set 13 | hanzhong
# Processing Record 1 of Set 14 | wagar
# Processing Record 2 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 14 | moses lake
# Processing Record 4 of Set 14 | terrace
# Processing Record 5 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 6 of Set 14 | ribeirao branco
# Processing Record 7 of Set 14 | fukue
# Processing Record 8 of Set 14 | wulanhaote
# City not found. Skipping...
# Processing Record 9 of Set 14 | vuktyl
# Processing Record 10 of Set 14 | urubicha
# Processing Record 11 of Set 14 | mopti
# Processing Record 12 of Set 14 | bulawayo
# Processing Record 13 of Set 14 | shache
# Processing Record 14 of Set 14 | paita
# Processing Record 15 of Set 14 | korla
# Processing Record 16 of Set 14 | mikhaylovskoye
# Processing Record 17 of Set 14 | krasnoye
# Processing Record 18 of Set 14 | matagami
# Processing Record 19 of Set 14 | russell
# Processing Record 20 of Set 14 | nouakchott
# Processing Record 21 of Set 14 | saint-leu
# Processing Record 22 of Set 14 | marostica
# Processing Record 23 of Set 14 | balykshi
# Processing Record 24 of Set 14 | vardo
# Processing Record 25 of Set 14 | acapulco
# Processing Record 26 of Set 14 | yumen
# Processing Record 27 of Set 14 | te anau
# Processing Record 28 of Set 14 | ontario
# Processing Record 29 of Set 14 | harper
# Processing Record 30 of Set 14 | moerai
# Processing Record 31 of Set 14 | wufeng
# Processing Record 32 of Set 14 | yelizovo
# Processing Record 33 of Set 14 | wembley
# Processing Record 34 of Set 14 | ipixuna
# Processing Record 35 of Set 14 | magaria
# Processing Record 36 of Set 14 | salinopolis
# Processing Record 37 of Set 14 | barabai
# Processing Record 38 of Set 14 | lazaro cardenas
# Processing Record 39 of Set 14 | roma
# Processing Record 40 of Set 14 | bartica
# Processing Record 41 of Set 14 | ilhabela
# Processing Record 42 of Set 14 | inuvik
# Processing Record 43 of Set 14 | quelimane
# Processing Record 44 of Set 14 | santa maria
# Processing Record 45 of Set 14 | deputatskiy
# Processing Record 46 of Set 14 | kemijarvi
# Processing Record 47 of Set 14 | ronne
# Processing Record 48 of Set 14 | barra
# Processing Record 49 of Set 14 | nuuk
# Processing Record 50 of Set 14 | honningsvag
# Processing Record 1 of Set 15 | las lomas
# Processing Record 2 of Set 15 | koshurnikovo
# Processing Record 3 of Set 15 | yunjinghong
# City not found. Skipping...
# Processing Record 4 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 15 | svetlogorsk
# Processing Record 6 of Set 15 | kozluk
# Processing Record 7 of Set 15 | yangambi
# Processing Record 8 of Set 15 | jalu
# Processing Record 9 of Set 15 | krasnovka
# Processing Record 10 of Set 15 | berlevag
# Processing Record 11 of Set 15 | kibala
# Processing Record 12 of Set 15 | rafsanjan
# Processing Record 13 of Set 15 | sungaipenuh
# Processing Record 14 of Set 15 | lorengau
# Processing Record 15 of Set 15 | tura
# Processing Record 16 of Set 15 | miyang
# Processing Record 17 of Set 15 | stephenville
# Processing Record 18 of Set 15 | nantucket
# Processing Record 19 of Set 15 | kaliua
# Processing Record 20 of Set 15 | gat
# Processing Record 21 of Set 15 | tongliao
# Processing Record 22 of Set 15 | omsukchan
# Processing Record 23 of Set 15 | vernon
# Processing Record 24 of Set 15 | obera
# Processing Record 25 of Set 15 | ordzhonikidze
# Processing Record 26 of Set 15 | butia
# Processing Record 27 of Set 15 | pontianak
# Processing Record 28 of Set 15 | kaka
# Processing Record 29 of Set 15 | mizdah
# Processing Record 30 of Set 15 | chumikan
# Processing Record 31 of Set 15 | tabou
# Processing Record 32 of Set 15 | kananga
# Processing Record 33 of Set 15 | santa ana
# Processing Record 34 of Set 15 | yatou
# Processing Record 35 of Set 15 | abaete
# Processing Record 36 of Set 15 | barentu
# Processing Record 37 of Set 15 | abha
# Processing Record 38 of Set 15 | alugan
# Processing Record 39 of Set 15 | bakchar
# Processing Record 40 of Set 15 | teahupoo
# Processing Record 41 of Set 15 | misratah
# Processing Record 42 of Set 15 | pangnirtung
# Processing Record 43 of Set 15 | waipawa
# Processing Record 44 of Set 15 | langfang
# Processing Record 45 of Set 15 | port hardy
# Processing Record 46 of Set 15 | ridgetown
# Processing Record 47 of Set 15 | shetpe
# Processing Record 48 of Set 15 | pendleton
# Processing Record 49 of Set 15 | maneadero
# Processing Record 50 of Set 15 | vila velha
# Processing Record 1 of Set 16 | coquimbo
# Processing Record 2 of Set 16 | scarborough
# Processing Record 3 of Set 16 | meadow lake
# Processing Record 4 of Set 16 | crab hill
# City not found. Skipping...
# Processing Record 5 of Set 16 | mumford
# Processing Record 6 of Set 16 | atbasar
# Processing Record 7 of Set 16 | sumter
# Processing Record 8 of Set 16 | hihifo
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 698

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Nanortalik      GL  60.1432  -45.2371     26.49        75          19
# 1        Hithadhoo      MV  -0.6000   73.0833     82.24        70          64
# 2         Portland      US  45.5234 -122.6762     75.00        23          20
# 3          Talnakh      RU  69.4865   88.3972    -12.08        95         100
# 4       Kastrakion      GR  39.7156   21.6181     37.00        79          26
# 5       Lavrentiya      RU  65.5833 -171.0000     16.92        89          75
# 6  Haines Junction      CA  60.7522 -137.5108     46.40        36          86
# 7          Aklavik      CA  68.2191 -135.0107     23.00        68          75
# 8        Busselton      AU -33.6500  115.3333     55.00        94          73
# 9  Arraial Do Cabo      BR -22.9661  -42.0278     77.00        65           0
#
#    Wind Speed Current Description
# 0       42.77          few clouds
# 1        5.17       broken clouds
# 2        8.05          few clouds
# 3       20.67     overcast clouds
# 4        1.57    scattered clouds
# 5        6.82       broken clouds
# 6        6.91     overcast clouds
# 7       11.50       broken clouds
# 8        8.34       broken clouds
# 9        6.91           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
